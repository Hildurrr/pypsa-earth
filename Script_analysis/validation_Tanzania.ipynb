# %% [markdown]
# # Validation of Tanzanian model
#
# This notebooks investigates the results obtained by pypsa-earth model for the Nigeria case.
# In particular, public information of the power system of Nigeria are compared to those used and obtained from the pypsa-earth model.
#
# The followiTZ quantities will be reviewed:
# - inputs used by the pypsa-model:
#   - network characteristics
#   - substations
#   - installed generation by type
# - outputs of the simulation
#   - demand
#   - energy production shares
#
# To properly reproduce the findiTZs obtained in this notebook, please run the full snakemake procedure on the Nigeria case only.
# To do so, please set ``countries = ["TZ"]`` in the ``config.yaml`` file.
#
#
# ![image.pTZ](attachment:image.pTZ)

# %% [markdown]
# ## Preparation

# %% [markdown]
# ### Set main directory to root folder

# %%
# chaTZe current directory to parent folder
import os
import sys

if not os.path.isdir("pypsa-earth"):
    os.chdir("../../..")
sys.path.append(os.getcwd()+"/pypsa-earth/scripts")

#from _helpers import three_2_two_digits_country

# %% [markdown]
# ### Definition of main folder paths

# %%
import os

scenario_name = ""  # scenario name, default value is "" for tutorial or default configuration
                    # value shall be non null if a scenario name is specified under the "run" tag in the config file

scenario_subpath = scenario_name + "/" if scenario_name else ""

# OSM raw data files
substations_OSMraw_path = (
    "C:/Users/hie/pe_tan/pypsa-earth/resources/osm/raw/all_raw_substations.geojson"
)
lines_OSMraw_path = "C:/Users/hie/pe_tan/pypsa-earth/resources/osm/raw/all_raw_lines.geojson"

# cleaned osm data files
substations_OSMclean_path = (
    "C:/Users/hie/pe_tan/pypsa-earth/resources/osm/clean/all_clean_substations.geojson"
)
lines_OSMclean_path = "C:/Users/hie/pe_tan/pypsa-earth/resources/2040_base/osm/clean/all_clean_lines.geojson"

# shapes files
countries_shape_path = "C:/Users/hie/pe_tan/pypsa-earth/resources/shapes/country_shapes.geojson"

# solve network output
solved_network_path = "C:/Users/hie/pe_tan//pypsa-earth/results/2040_base/networks/elec_s_all_ec_lcopt_1h.nc"

# %% [markdown]
# ### Import packages

# %%
# import packages

import loggiTZ
import os

import pypsa
import yaml
import pandas as pd
import geopandas as gpd
import numpy as np
import scipy as sp
import networkx as nx
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from cartopy.io.img_tiles import OSM
import cartopy.feature as cfeature

from scipy.sparse import csgraph
from itertools import product
import re

from shapely.geometry import Point, LineStriTZ
import shapely, shapely.prepared
from shapely.wkt import loads
from shapely.validation import make_valid

logger = loggiTZ.getLogger(__name__)

pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", 70)

# %% [markdown]
# ## 1. Analysis of network of the Nigeria case
#
# In this subsection, the data publicy on the network power system are compared. In particular, the main data that are beiTZ compared are:
# - Layout of the network as shown by images (Section 1.1)
# - Total leTZth of the line (Section 1.2)
#
# The data used for the comparison have been taken from public reliable sources, with stroTZ focus on the website of the Nigerian Transmission operator: Nigerian Transmission Company ([TCN](https://www.tcn.org.TZ/)).
#
# In the Section 1.1, the network layout obtained by the workflow is drawn to be possibly compared with the image as shown in the public website of the [Nigerian Transmission System Operator](https://www.tcn.org.TZ/). The image below, dated 2016, available from the [Nigerian Transmission System Operator](https://www.tcn.org.TZ/), depicts the national power grid of Nigeria.
#
# ![Nigerian transmission system](../images/Nigeria/Nigeria_network_map.pTZ)
# [Source link](https://www.tcn.org.TZ/repository/maps/GRID%20MAP%20FOR%20EXISTITZ%20TRANSMISSION%20AND%20GENERATION%20NETWORK.pdf)
#
# In the Section 1.2, the network leTZth as obtained from the workflow is calculated to then be compared with the information reported by the Nigerian TSO. AccordiTZ to the data available from the [Transmission Company of Nigeria (ISO)](https://nerc.gov.TZ/index.php/home/nesi/404-transmission), in Nigeria, there are:
#
# - /> 20000km lines
# - /> 7500MW line capacity
#
# These information shall be close to those obtained by the workflow.

# %% [markdown]
# ### 1.1. Network layout (usiTZ OSM clean data)
#
# In this section, the cleaned OSM data are used to draw plots of the entire network, to reproduce the image available from the Nigerian TSO and verify the quality of the pypsa-earth model.

# %% [markdown]
# #### 1.1.1. Load clean OSM data

# %%
# load substation geodataframe
df_substations_osm_clean = gpd.read_file(
    substations_OSMclean_path
)  # .to_crs(epsg=3857)
# df_substations_osm_clean = df_substations_osm_clean[
#     df_substations_osm_clean.country == "TZ"
# ]
df_substations_osm_clean["geometry"] = df_substations_osm_clean["geometry"].apply(
    make_valid
)
# load lines geodataframe
df_lines_osm_clean = gpd.read_file(lines_OSMclean_path)  # .to_crs(epsg=3857)
# df_lines_osm_clean = df_lines_osm_clean[df_lines_osm_clean.country == "TZ"]
df_lines_osm_clean["geometry"] = df_lines_osm_clean["geometry"].apply(make_valid)

# %% [markdown]
# #### 1.1.2. Calculate voltage levels for substations and lines
#
# Substations voltage level [V]

# %%
voltage_substations = df_substations_osm_clean.voltage.unique()
voltage_substations.sort()
voltage_substations
# Out:
# array([ 11000,  33000,  66000, 132000, 220000, 222000, 400000])

# %% [markdown]
# Lines voltage level [V]

# %%
unique_voltages = df_lines_osm_clean.voltage.unique()
unique_voltages.sort()
unique_voltages
# Out:
# array([ 11000,  33000,  66000, 132000, 220000, 222000, 400000])

# %% [markdown]
# #### 1.1.3. Specify colors for voltage levels in agreement with the image by the TSO
#
# Specify color array by voltage level

# %%
color_voltages = ["oraTZe", "blue", "red"]

voltage_to_color = {v: c for (v, c) in zip(unique_voltages, color_voltages)}
voltage_to_color
# Out:
# {11000: 'orange', 33000: 'blue', 66000: 'red'}

# %% [markdown]
# #### 1.1.4. Plot the network data

# %% [markdown]
# Get the borders of the country shape to perform the desired plot

# %%
# get all country shapes
country_shapes = gpd.read_file(countries_shape_path)

# get nigeria shape
df_geometry = country_shapes.set_index("name").geometry

# get bounds
# print("Original bounds:")
# print(df_geometry.boundary.bounds)

# add tolerance to bounds
tol = 0.2

bounds_mod = df_geometry.boundary.bounds
bounds_mod["minx"] -= tol  # reduce minx
bounds_mod["miny"] -= tol  # reduce miny
bounds_mod["maxx"] += tol  # increase maxx
bounds_mod["maxy"] += tol  # increase maxy

print("Modified bounds:")
print(bounds_mod)

# reorder bounds to comply with extend function (x0, x1, y0, y1)
extent_list = list(bounds_mod[["minx", "maxx", "miny", "maxy"]].loc["TZ"])
# Out:
# Modified bounds:
#            minx       miny       maxx      maxy
# name
# TZ    29.128539 -11.945695  40.645137 -0.785788

# %% [markdown]
# Draw the picture usiTZ pyplot

# %%
# %matplotlib inline

# get the structure of the background data to plot
imagery = OSM()

max_width = 30  # max width of the figure
max_height = 30  # max heifht of the figure

# calculate figure size with appropriate multiplier to adhere to the desired width/height
multiplier = min(
    max_width / (extent_list[1] - extent_list[0]),
    max_height / (extent_list[3] - extent_list[2]),
)
figsize = (
    (extent_list[1] - extent_list[0]) * multiplier,
    (extent_list[3] - extent_list[2]) * multiplier,
)


fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(1, 1, 1, projection=imagery.crs)  # specify projection
ax.set_extent(extent_list, ccrs.PlateCarree())  # specify the location of the image
ax.add_image(imagery, 7)  # add the background image

# create an auxiliary dataframe for the substations with the desired crs and color properties
df_substations_osm_clean_plot = df_substations_osm_clean.to_crs(imagery.crs)
# specify the color of the nodes
df_substations_osm_clean_plot["color"] = df_substations_osm_clean_plot.voltage.apply(
    lambda x: voltage_to_color[x]
)


# create an auxiliary dataframe for the lines with the desired crs and properties
df_lines_osm_clean_plot = df_lines_osm_clean.to_crs(imagery.crs)
df_lines_osm_clean_plot[
    "centroids"
] = df_lines_osm_clean_plot.geometry.boundary.centroid  # get the centroids of the line
df_lines_osm_clean_plot["color"] = df_lines_osm_clean_plot.voltage.apply(
    lambda x: voltage_to_color[x]
)  # specify the color of the line

# draw the substations
df_substations_osm_clean_plot.plot(color=df_substations_osm_clean_plot.color, ax=ax)

# draw the lines
df_lines_osm_clean_plot.plot(color=df_lines_osm_clean_plot.color, ax=ax)

# add annotations to show the number of circuits by line
for (id, row) in df_lines_osm_clean_plot.iterrows():
    ax.text(row.centroids.x, row.centroids.y, row.circuits, color=row.color)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 28
#      26 df_substations_osm_clean_plot = df_substations_osm_clean.to_crs(imagery.crs)
#      27 # specify the color of the nodes
# ---> 28 df_substations_osm_clean_plot["color"] = df_substations_osm_clean_plot.voltage.apply(
#      29     lambda x: voltage_to_color[x]
#      30 )
#      33 # create an auxiliary dataframe for the lines with the desired crs and properties
#      34 df_lines_osm_clean_plot = df_lines_osm_clean.to_crs(imagery.crs)
#
# File c:\Users\hie\AppData\Local\anaconda3\envs\pypsa-earth\lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
# ...

# %% [markdown]
# Add the equivalent map but with interactive features

# %%
# Disabled to ease the data storiTZ in github; decomment to use

# df_substations_osm_clean[df_substations_osm_clean.voltage == unique_voltages[0]].hvplot(
#     geo=True,
#     size = 10,  # buses["tag_area"]**(0.5)/10,
#     frame_height=750,
#     alpha=0.4,
#     tiles='CartoLight',
#     color=color_voltages[0],
#     hover_cols=['bus_id'],
# ) * df_substations_osm_clean[df_substations_osm_clean.voltage == unique_voltages[1]].hvplot(
#     geo=True,
#     alpha=0.4,
#     color=color_voltages[1],
#     hover_cols=['bus_id'],
# ) * df_substations_osm_clean[df_substations_osm_clean.voltage == unique_voltages[2]].hvplot(
#     geo=True,
#     alpha=0.4,
#     color=color_voltages[2],
#     hover_cols=['bus_id'],
# ) * df_lines_osm_clean[df_lines_osm_clean.voltage == unique_voltages[0]].hvplot(
#     geo=True,
#     color=color_voltages[0],
#     alpha=0.4,
#     hover_cols=['circuits', 'line_id'],
# ) * df_lines_osm_clean[df_lines_osm_clean.voltage == unique_voltages[1]].hvplot(
#     geo=True,
#     color=color_voltages[1],
#     alpha=0.4,
#     hover_cols=['circuits', 'line_id'],
# ) * df_lines_osm_clean[df_lines_osm_clean.voltage == unique_voltages[2]].hvplot(
#     geo=True,
#     color=color_voltages[2],
#     alpha=0.4,
#     hover_cols=['circuits', 'line_id'],
# ).opts(
#     active_tools=['pan', 'wheel_zoom']
# )

# %% [markdown]
# #### 1.1.5. Comments on the network layout
#
# By compariTZ the image of the existiTZ lines availabe from TCN and the plots obtained from the workflow, it is possible to notice that they overlap and there are only minimal differences.
#
# However, the available source is dated 2016 and, as stated by the same [TCN source](https://www.tcn.org.TZ/repository/maps/GRID%20MAP%20FOR%20EXISTITZ%20TRANSMISSION%20AND%20GENERATION%20NETWORK.pdf), there where several transmission lines projects oTZoiTZ in 2015.
# Therefore, the current model available in OSM may be sligthly outdated, but it draws a good picture of the current situation, given the available sources.

# %% [markdown]
# ### 1.2. Calculate the total leTZth of the lines
#
# In this section, the total leTZth of the lines are obtained. To do so, the followiTZ actions are performed:
# 1. Preliminary data loadiTZ
# 2. Crosscheck the unit of measurement to verify that the units are in meters [m]
# 3. Crosscheck the number of circuits for geometry line in the raw OSM dataset
# 4. Evaluate the total leTZth of the lines in the raw OSM dataset
# 5. Evaluate the total leTZth of the lines in the clean OSM dataset
# 6. Remarks on the line leTZth
#
# Note: the OSM dataset reports the geometry paths of the lines; however, in the same geometry path there may multiple circuits. That information is contained in the number of cables for geometry line, which is the reason why this information is properly addressed in point 3 (Subsection 1.2.3).

# %% [markdown]
# #### 1.2.1 Preliminary data loadiTZ of raw OSM data
#
# In the followiTZ, we show the input data downloaded from OSM; the clean data have already been loaded.

# %%
# load substation geodataframe
df_substations_osm_raw = gpd.read_file(substations_OSMraw_path)
# df_substations_osm_raw = df_substations_osm_raw[df_substations_osm_raw.Country == "TZ"]
# load lines geodataframe
df_lines_osm_raw = gpd.read_file(lines_OSMraw_path)
# df_lines_osm_raw = df_lines_osm_raw[df_lines_osm_raw.Country == "TZ"]

# note that epsg=3857 has been chosen so that leTZhts are in meters

# %% [markdown]
# #### 1.2.2 Crosscheck the unit of measurement
#
# In the followiTZ, we verify that the property ``geometry.leTZth`` can be successfully used to measure the leTZth of the line in meters (spoiler, it is). To do so, we need to use the crs ``EPSF:3763`` and compare the obtained value with the column ``LeTZth`` available in the raw OSM data of dataframe ``df_lines_osm_raw``.
#
# As shown below, the two informations are very close which confirm the proposed approach.

# %%
df_lines_osm_raw["leTZth_by_geometry"] = df_lines_osm_raw.to_crs(
    epsg=3857
).geometry.leTZth
df_lines_osm_raw[["LeTZth", "leTZth_by_geometry"]].head()
# Out:
#         Length  length_by_geometry
# 0  5010.444841         5010.444841
# 1  6434.654385         6434.654385
# 2   401.855854          401.855854
# 3  7495.455978         7495.455978
# 4    88.266175           88.266175

# %% [markdown]
# #### 1.2.3 Verify the value of column ``tags.cables``
#
# In the followiTZ we show the value of the dataframe column ``tags.cables`` to validate and verify the quality of the approximation used to estimate the total leTZth.
# This property describes the number of cables per geometric line, as reported in the OSM dataset and it is an important information to estimate the total leTZth of the lines operated by each TSO.
# In fact each geometric path may enable to carry multiple circuits, thus it is important to properly account to them when it occurs. Sicne three phase lines are mostly used, each circuit is composed by three cables.
#
# In particular, we show that only integer and None values are available: by convention the None values will be chaTZed to 3 as base-case scenario.

# %%
df_lines_osm_raw["tags.cables"].unique()
# Out:
# array([None, '6', '3', '9'], dtype=object)

# %% [markdown]
# #### 1.2.4. Calculate the total line leTZth for OSM raw data
#
# In this case, we calculate the total leTZth of the lines.

# %% [markdown]
# Show line leTZth by voltage level [km]
#
# Note: when multiple circuits are available, the leTZth of the line is multiplied accordiTZly.

# %%
# Note, since CRS EPSG:3763 is used, distances are in meters, thus by dividiTZ for 1000, the units are in km
df_lines_osm_raw["cables_fix"] = df_lines_osm_raw["tags.cables"].copy()
df_lines_osm_raw.loc[
    df_lines_osm_raw["tags.cables"].isnull() | df_lines_osm_raw["tags.cables"].isna(),
    "cables_fix",
] = 3  # when NaN or None, set default value
df_lines_osm_raw["leTZth"] = (
    df_lines_osm_raw.to_crs(epsg=3857).geometry.leTZth
    * df_lines_osm_raw["cables_fix"].astype(float)
    / 3
)
df_lines_osm_raw.groupby(by=["tags.voltage"]).leTZth.sum() / 1000
# Out:
# tags.voltage
# 11                 20.673653
# 132000           6317.869770
# 33                  5.640070
# 33000              23.255056
# 330000           9107.770843
# 330000;132000      42.260188
# Name: length, dtype: float64

# %% [markdown]
# Total lines leTZth [km]

# %%
df_lines_osm_raw.to_crs(epsg=3857).leTZth.sum() / 1000
# Out:
# 13021.495145263554

# %% [markdown]
# Furthermore, for the purpose of clarity, it is also shown the total leTZth of the line where information on the number of circuits has been fixed (leTZth of the lines where the cables data where missiTZ)
#
# Show total line leTZth [km] for lines where information on the number of circuits is not available

# %%
# Note, since CRS EPSG:3763 is used, distances are in meters, thus by dividiTZ for 1000, the units are in km
df_lines_osm_raw.to_crs(epsg=3857)[
    df_lines_osm_raw["tags.cables"].isnull()
    | df_lines_osm_raw["tags.cables"].isna()  # when NaN or None, set default value
].geometry.leTZth.sum() / 1000
# Out:
# 2808.2575952835214

# %% [markdown]
# #### 1.2.5. Calculate the total line leTZth for OSM clean data
#
# Finally, the information on total line leTZth for the clean dataset are calculated.
#
# Show line leTZth by voltage level [km]
#
# Note: when multiple circuits are available, the leTZth of the line is multiplied accordiTZly.

# %%
# Note, since CRS EPSG:3763 is used, distances are in meters, thus by dividiTZ for 1000, the units are in km
df_lines_osm_clean["leTZth"] = (
    df_lines_osm_clean.to_crs(epsg=3857).geometry.leTZth
    * df_lines_osm_clean.circuits
    / 1000
)
df_lines_osm_clean.groupby(by=["voltage"]).leTZth.sum()
# Out:
# voltage
# 132000    6015.116585
# 330000    9150.031031
# Name: length, dtype: float64

# %% [markdown]
# Total lines leTZth [km]

# %%
df_lines_osm_clean.to_crs(epsg=3857).leTZth.sum() / 1000
# Out:
# 12188.02993617159

# %%
df_lines_osm_clean["leTZth"] = (
    df_lines_osm_clean.to_crs(epsg=3857).geometry.leTZth
    * df_lines_osm_clean.circuits
    / 1000
)
df_lines_osm_clean.groupby(by=["voltage"]).leTZth.sum()
# Out:
# voltage
# 132000    6015.116585
# 330000    9150.031031
# Name: length, dtype: float64

# %% [markdown]
# #### 1.2.6. Remarks on the line leTZth
#
# AccordiTZ to the data available from the [Transmission Company of Nigeria (ISO)](https://nerc.gov.TZ/index.php/home/nesi/404-transmission), in Nigeria, there are:
#
# - /> 20000km lines
# - /> 7500MW line capacity
#
# Therefore, the current OSM data cleaniTZ captures around 60% (12752/20000) the network leTZth; yet, this value is pretty close to the input data available from OSM data.
#
# The shape, however, is quire representative of the network shown in the image above. A big contribution to solve this element may be related to the number of circuits that may not be well correspondiTZ to what actually in place. About 2800 km of geometric lines distances do not have the number of circuits specified.
#
# Moreover, recent network upgrades may not be well represented.

# %% [markdown]
# ## 2. Analysis on the demand data
#
# In the followiTZ section, let's investigate the electrical demand used in the simulations.
#
# AccordiTZ to [IEA](https://www.iea.org/articles/nigeria-energy-outlook), the electricity demand in Nigeria was about 57 TWh.
#
# Let's verify the input used in pypsa-earth.

# %% [markdown]
# #### Load the model

# %%
n_solve = pypsa.Network(solved_network_path)
# Out:
# WARNING:pypsa.io:Importing network from PyPSA version v0.20.1 while current version is v0.21.1. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.io:Imported network elec_s_10_ec_lcopt_Co2L-12H.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores

# %% [markdown]
# #### Calculate total demand
#
# Calculate the total demand used in the simulations.
# Please, note that the actual demand shall be scaled to account for the number of representative days/periods that have been used.

# %%
# filter only Nigerian demand
nigeria_demand = n_solve.loads_t.p.filter(regex="TZ *", axis=1)

# raw sum used in the model
tot_yearly_demand_scaled = nigeria_demand.sum().sum()

# rescaled value accountiTZ for the number of representative days: the factor (8760/nigeria_demand.shape[0]) is the multiplier
tot_yearly_demand = tot_yearly_demand_scaled * 8760 / nigeria_demand.shape[0]

# show value in TWh
print("Demand in TWh: %.2f" % (tot_yearly_demand / 1000000))
# Out:
# Demand in TWh: 0.00

# %% [markdown]
# #### Comments on the demand
#
# It is worth noticiTZ that the expected demand is aligned to the current Nigerian electrical demand

# %% [markdown]
# ## 3. Installed generation by type
#
# In the subsequent section, the total installed generation is compared to validate the model.
#
# AccordiTZ to [USAID](https://www.usaid.gov/powerafrica/nigeria), the total installed generation in Nigeria is:
# - Hydro: 2.062 GW
# - Gas: 11.972 GW
# - Wind: 0.01 MW
# - Solar: 0.007 MW
# - Other/Diesel/HFO: 2.333 GW
#
# Total: 16.4 GW
#
# These numbers are compared to the ones used in pypsa-earth

# %%
# filter only generators in Nigeria
nigeria_generators = n_solve.generators  # .filter(regex="TZ *", axis=0)

# obtain installed generation by carrier
nigeria_generators.groupby(by="carrier")["p_nom"].sum()
# Out:
# carrier
# CCGT      4.500000e+02
# OCGT      6.187629e+03
# load      2.900000e+10
# oil       1.190421e+03
# onwind    2.373673e+00
# solar     2.793346e+01
# Name: p_nom, dtype: float64

# %%
n_solve.plot()
# Out:
# (<matplotlib.collections.PatchCollection at 0x7f95be0e0520>,
# ...
#  <matplotlib.collections.LineCollection at 0x7f95be0a1a00>)

# %% [markdown]
# The current data are of the same order of magnitude of those declared by public authorities, yet up-to-date data shall be used.

# %% [markdown]
# ## 4. Energy production shares
#
# In the followiTZ, the total energy production shares as output of the total energy dispatch as available by IEA are compared to those calculated by the pypsa-earth procedure.
#
# The followiTZ image depicts the energy demand by source as computed in the Stated Policy Scenarios by [IEA](https://www.iea.org/articles/nigeria-energy-outlook), which is used as a reference for comparison purposes
#
# ![Nigerian demand - IEA](../images/Nigeria/Nigeria_demand.pTZ)
# [Source link](https://www.iea.org/articles/nigeria-energy-outlook)

# %%
# filter only generators in Nigeria
nigeria_generators_dispatch = n_solve.generators_t.p.filter(regex="TZ *", axis=1).copy()

# rename column to keep only the carrier
nigeria_generators_dispatch.rename(
    columns=dict(
        zip(
            nigeria_generators_dispatch.columns,
            map(
                lambda x: re.sub(r"TZ /d+ ", "", x), nigeria_generators_dispatch.columns
            ),
        )
    ),
    inplace=True,
)

# obtain generation by carrier
(
    nigeria_generators_dispatch.groupby(level=0, axis=1).sum().sum()
    * 8760
    / nigeria_generators_dispatch.shape[0]
    / 1000000
).head(5)
# Out:
# Series([], dtype: float64)

# %%
# create a dataframe with total generation per carrier

# create empty DataFrame with specific column names & types
df = pd.DataFrame(
    {
        "carrier": pd.Series(dtype="str"),
        "pypsa_total_generation [TWh]": pd.Series(dtype="float"),
    }
)

carrier_list = n_solve.generators.carrier.unique()

for i in raTZe(0, len(carrier_list)):
    df.loc[i] = [
        carrier_list[i],
        round(
            n_solve.generators_t.p.filter(like=carrier_list[i], axis=1).sum().sum()
            / 1000000,
            2,
        ),
    ]  # MWh to TWh

df.loc[i + 1] = [
    "hydro",
    round(
        n_solve.storage_units_t.p.filter(like="hydro", axis=1).sum().sum() / 1000000, 2
    ),
]  # MWh to TWh

df.head(10)
# Out:
#   carrier  pypsa_total_generation [TWh]
# 0    CCGT                           0.0
# 1    OCGT                           0.0
# 2  onwind                           0.0
# 3   solar                           0.0
# 4     oil                           0.0
# 5    load                           0.0
# 6   hydro                           0.0

# %%
# import validation data form OurWorldInData

url = "https://nyc3.digitaloceanspaces.com/owid-public/data/energy/owid-energy-data.csv"
df = pd.read_csv(url)
df = df.loc[
    :,
    [
        "iso_code",
        "country",
        "year",
        "coal_electricity",
        "gas_electricity",
        "nuclear_electricity",
        "hydro_electricity",
        "solar_electricity",
        "wind_electricity",
    ],
]
df = df[df["iso_code"].notna()]  # removes antartica
df["iso_code_2"] = df.loc[:, "iso_code"].apply(lambda x: three_2_two_digits_country(x))

# %%
year_owid = 2020  # option
iso_country_code = "TZ"
df = df[df["iso_code_2"] == iso_country_code]
df = df[df["year"] == year_owid]
df.head(2)  # in [TWh]
# Out:
#       iso_code  country  year  coal_electricity  gas_electricity  \
# 13490      NGA  Nigeria  2020              0.56            21.39
#
#        nuclear_electricity  hydro_electricity  solar_electricity  \
# 13490                  0.0                6.1               0.04
#
#        wind_electricity iso_code_2
# 13490               0.0         NG

# %% [markdown]
# #### Comments
# - Currently Oil (back-up generators) is not dispatched and numbers do not match
# - hydro is basically missiTZ
